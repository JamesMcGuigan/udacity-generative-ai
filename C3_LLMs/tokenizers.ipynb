# %%
from transformers import AutoTokenizer

text = "Lorem ipsum dolor sit amet, consectetur adipiscing elit."
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
tokens    = tokenizer.tokenize(text)
print(tokens)
# Out:
# ['lore', '##m', 'ip', '##sum', 'do', '##lor', 'sit', 'am', '##et', ',', 'con', '##se', '##ct', '##et', '##ur', 'adi', '##pis', '##cing', 'eli', '##t', '.']

# %%
tokenizer_models = [
"bert-base-uncased", "bert-base-cased",
"roberta-base", "roberta-large",
"gpt2", "gpt2-medium",
"t5-small", "t5-base",
"xlnet-base-cased",
"distilbert-base-uncased",
"albert-base-v2",
"facebook/bart-base",
]
for model in tokenizer_models:
    tokenizer = AutoTokenizer.from_pretrained(model)
    tokens = tokenizer.tokenize(text)
    print(tokenizer.model_max_length, model, tokens, "\n")
# Out:
# 512 bert-base-uncased ['lore', '##m', 'ip', '##sum', 'do', '##lor', 'sit', 'am', '##et', ',', 'con', '##se', '##ct', '##et', '##ur', 'adi', '##pis', '##cing', 'eli', '##t', '.']
#
# 512 bert-base-cased ['Lo', '##rem', 'i', '##ps', '##um', 'do', '##lor', 'sit', 'am', '##et', ',', 'con', '##sect', '##et', '##ur', 'ad', '##ip', '##is', '##cing', 'el', '##it', '.']
#
# 512 roberta-base ['L', 'orem', 'Ġ', 'ips', 'um', 'Ġd', 'olor', 'Ġsit', 'Ġam', 'et', ',', 'Ġcon', 'sect', 'et', 'ur', 'Ġadip', 'is', 'cing', 'Ġel', 'it', '.']
#
# 512 roberta-large ['L', 'orem', 'Ġ', 'ips', 'um', 'Ġd', 'olor', 'Ġsit', 'Ġam', 'et', ',', 'Ġcon', 'sect', 'et', 'ur', 'Ġadip', 'is', 'cing', 'Ġel', 'it', '.']
#
# 1024 gpt2 ['L', 'orem', 'Ġ', 'ips', 'um', 'Ġd', 'olor', 'Ġsit', 'Ġam', 'et', ',', 'Ġcon', 'sect', 'et', 'ur', 'Ġadip', 'is', 'cing', 'Ġel', 'it', '.']
#
# 1024 gpt2-medium ['L', 'orem', 'Ġ', 'ips', 'um', 'Ġd', 'olor', 'Ġsit', 'Ġam', 'et', ',', 'Ġcon', 'sect', 'et', 'ur', 'Ġadip', 'is', 'cing', 'Ġel', 'it', '.']
#
# 512 t5-small ['▁Lor', 'e', 'm', '▁', 'ips', 'um', '▁do', 'lor', '▁sit', '▁', 'a', 'met', ',', '▁con', 'sec', 't', 'e', 'tur', '▁', 'a', 'dip', 'is', 'c', 'ing', '▁', 'e', 'lit', '.']
#
# 1000000000000000019884624838656 t5-base ['▁Lor', 'e', 'm', '▁', 'ips', 'um', '▁do', 'lor', '▁sit', '▁', 'a', 'met', ',', '▁con', 'sec', 't', 'e', 'tur', '▁', 'a', 'dip', 'is', 'c', 'ing', '▁', 'e', 'lit', '.']
#
# 1000000000000000019884624838656 xlnet-base-cased ['▁Lore', 'm', '▁', 'ip', 'sum', '▁do', 'lor', '▁sit', '▁a', 'met', ',', '▁con', 'sec', 'te', 'tur', '▁', 'adi', 'pi', 's', 'cing', '▁', 'eli', 't', '.']
#
# 512 distilbert-base-uncased ['lore', '##m', 'ip', '##sum', 'do', '##lor', 'sit', 'am', '##et', ',', 'con', '##se', '##ct', '##et', '##ur', 'adi', '##pis', '##cing', 'eli', '##t', '.']
#
# 512 albert-base-v2 ['▁lore', 'm', '▁i', 'ps', 'um', '▁do', 'lor', '▁sit', '▁a', 'met', ',', '▁con', 'sec', 'te', 'tur', '▁', 'adi', 'pis', 'cing', '▁eli', 't', '.']
#
# 1000000000000000019884624838656 facebook/bart-base ['L', 'orem', 'Ġ', 'ips', 'um', 'Ġd', 'olor', 'Ġsit', 'Ġam', 'et', ',', 'Ġcon', 'sect', 'et', 'ur', 'Ġadip', 'is', 'cing', 'Ġel', 'it', '.']
